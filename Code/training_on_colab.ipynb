# %%
# !pip install --upgrade pip

# %% [markdown]
# ## Mount personnal drive : second time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

#path = '/content/drive/MyDrive/DeepLearningTP5/Code'
path = '/content/drive/MyDrive/TP5'

try:
    os.chdir(path)
    print("Current working directory: {0}".format(os.getcwd()))
except FileNotFoundError:
    print("Directory: {0} does not exist".format(path))
except NotADirectoryError:
    print("{0} is not a directory".format(path))
except PermissionError:
    print("You do not have permissions to change to {0}".format(path))
# Out:
# Current working directory: /content/drive/MyDrive/TP5

# %% [markdown]
# ## Installation

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/facebookresearch/jacobian_regularizer (to revision c9a0365c835b418ec530a8c9dc79f794bb4cfb08) to /tmp/pip-install-xewec4kx/jacobian_c511f92cc9894421af636b7f3b202e3c
#   Running command git clone -q https://github.com/facebookresearch/jacobian_regularizer /tmp/pip-install-xewec4kx/jacobian_c511f92cc9894421af636b7f3b202e3c
#   Running command git rev-parse -q --verify 'sha^c9a0365c835b418ec530a8c9dc79f794bb4cfb08'
#   Running command git fetch -q https://github.com/facebookresearch/jacobian_regularizer c9a0365c835b418ec530a8c9dc79f794bb4cfb08
# ...
#      |████████████████████████████████| 1.3 MB 10.4 MB/s
# ...
#      |████████████████████████████████| 103 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 829 kB 43.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 159 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 11.5 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 142 kB 51.7 MB/s
# ...

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 8.1 MB/s
# ...
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# ...
#   Using cached sentry_sdk-1.0.0-py2.py3-none-any.whl (131 kB)
# ...
#   Using cached GitPython-3.1.14-py3-none-any.whl (159 kB)
# ...
#   Using cached configparser-5.0.2-py3-none-any.whl (19 kB)
# ...
#   Using cached subprocess32-3.5.4.tar.gz (97 kB)
# ...
#   Using cached shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# ...
#   Using cached pathtools-0.1.2.tar.gz (11 kB)
# ...
#   Using cached gitdb-4.0.5-py3-none-any.whl (63 kB)
# ...
#   Using cached smmap-3.0.5-py2.py3-none-any.whl (25 kB)
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6488 sha256=b17d49ab3cf5f9e729d2a79c2e37c17c48217606146215c6e7e687e836df0607
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %%
# !pip install pytorch_lightning
# Out:
# ...
#      |████████████████████████████████| 821 kB 7.1 MB/s
# ...
#   Using cached PyYAML-5.3.1.tar.gz (269 kB)
# ...
#   Using cached fsspec-0.8.7-py3-none-any.whl (103 kB)
# ...
#   Using cached future-0.18.2.tar.gz (829 kB)
# ...
#   Using cached aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
# ...
#   Using cached multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
# ...
#      |████████████████████████████████| 294 kB 21.1 MB/s
# ...
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=17df6ce861517d464a4950a48b8b50f4ca4ce22e971e67ad4388f3ce96036c67
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=31dcd05ae9948aaf82b62fcfde73214fb2f6e2149a365d9d547156bae3498493
# ...

# %% [markdown]
# ## Train

# %%
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import torch
print(torch.cuda.device_count())
# Out:
# 1

# %%
# CUDA_VISIBLE_DEVICES = 1

# %%
# !python training_model.py --gpus -1 --epochs 25 --delta_t 0.001 --batch_size 1000 --n_iter_train 2000000 --n_iter_val 200000 --n_iter_test 20000 --lr 1e-2
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# param: torch.Size([15, 3])
# param: torch.Size([15])
# param: torch.Size([15, 15])
# param: torch.Size([15])
# param: torch.Size([15, 15])
# param: torch.Size([15])
# param: torch.Size([3, 15])
# param: torch.Size([3])
# wandb: Currently logged in as: mimene (use `wandb login --relogin` to force relogin)
# 2021-03-09 22:23:02.045438: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.21
# wandb: Syncing run radiant-butterfly-11
# wandb: ⭐️ View project at https://wandb.ai/mimene/test_rossler
# wandb: 🚀 View run at https://wandb.ai/mimene/test_rossler/runs/1d8g359a
# wandb: Run data is saved locally in /content/drive/My Drive/TP5/wandb/run-20210309_222300-1d8g359a
# wandb: Run `wandb offline` to turn off syncing.
#
#
#   | Name               | Type       | Params
# ...
